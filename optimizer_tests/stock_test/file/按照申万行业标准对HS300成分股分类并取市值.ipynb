# %%
# 导入相关的 Python 库

import numpy as np
import statsmodels as sm
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 

import statsmodels.api as sm

import rqdatac
# 填写 RQData 账号和密码

rqdatac.init("ricequant", "8ricequant8")

SHENWAN_INDUSTRY_MAP = {
    "801010.INDX": "农林牧渔",
    "801020.INDX": "采掘",
    "801030.INDX": "化工",
    "801040.INDX": "钢铁",
    "801050.INDX": "有色金属",
    "801080.INDX": "电子",
    "801110.INDX": "家用电器",
    "801120.INDX": "食品饮料",
    "801130.INDX": "纺织服装",
    "801140.INDX": "轻工制造",
    "801150.INDX": "医药生物",
    "801160.INDX": "公用事业",
    "801170.INDX": "交通运输",
    "801180.INDX": "房地产",
    "801200.INDX": "商业贸易",
    "801210.INDX": "休闲服务",
    "801230.INDX": "综合",
    "801710.INDX": "建筑材料",
    "801720.INDX": "建筑装饰",
    "801730.INDX": "电气设备",
    "801740.INDX": "国防军工",
    "801750.INDX": "计算机",
    "801760.INDX": "传媒",
    "801770.INDX": "通信",
    "801780.INDX": "银行",
    "801790.INDX": "非银金融",
    "801880.INDX": "汽车",
    "801890.INDX": "机械设备"
}

benchmark_code = "000300.XSHG"  # 沪深300
date = '20161231'
i_c = rqdatac.index_components(benchmark_code, date)
benchmark = pd.DataFrame(index=i_c)
benchmark["industry"] = [rqdatac.shenwan_instrument_industry(s, date) for s in benchmark.index]
market_cap = rqdatac.get_fundamentals(query(fundamentals.eod_derivative_indicator.market_cap).filter(fundamentals.eod_derivative_indicator.stockcode.in_(benchmark.index)), entry_date=date)
# Out:
#                         industry
# 000671.XSHE   (801180.INDX, 房地产)
# 000001.XSHE    (801780.INDX, 银行)
# 600060.XSHG  (801110.INDX, 家用电器)
# 002470.XSHE    (801030.INDX, 化工)
# 600754.XSHG  (801210.INDX, 休闲服务)
# 601398.XSHG    (801780.INDX, 银行)
# 600893.XSHG  (801740.INDX, 国防军工)
# 601127.XSHG    (801880.INDX, 汽车)
# 000503.XSHE  (801150.INDX, 医药生物)
# 603885.XSHG  (801170.INDX, 交通运输)
# 002142.XSHE    (801780.INDX, 银行)
# 002673.XSHE  (801790.INDX, 非银金融)
# 300315.XSHE    (801760.INDX, 传媒)
# 600649.XSHG                 None
# 600583.XSHG    (801020.INDX, 采掘)
# 000166.XSHE  (801790.INDX, 非银金融)
# 600104.XSHG    (801880.INDX, 汽车)
# 002049.XSHE    (801080.INDX, 电子)
# 600332.XSHG  (801150.INDX, 医药生物)
# 000559.XSHE    (801880.INDX, 汽车)
# 601866.XSHG  (801170.INDX, 交通运输)
# 601216.XSHG    (801030.INDX, 化工)
# 600867.XSHG  (801150.INDX, 医药生物)
# 002500.XSHE  (801790.INDX, 非银金融)
# 601688.XSHG  (801790.INDX, 非银金融)
# 002027.XSHE    (801760.INDX, 传媒)
# 002007.XSHE  (801150.INDX, 医药生物)
# 000718.XSHE   (801180.INDX, 房地产)
# 002008.XSHE    (801080.INDX, 电子)
# 600029.XSHG  (801170.INDX, 交通运输)
# ...                          ...
# 000776.XSHE  (801790.INDX, 非银金融)
# 601888.XSHG  (801210.INDX, 休闲服务)
# 002024.XSHE  (801200.INDX, 商业贸易)
# 300002.XSHE   (801750.INDX, 计算机)
# 002153.XSHE   (801750.INDX, 计算机)
# 000938.XSHE   (801750.INDX, 计算机)
# 601555.XSHG  (801790.INDX, 非银金融)
# 002131.XSHE    (801760.INDX, 传媒)
# 300251.XSHE    (801760.INDX, 传媒)
# 002456.XSHE    (801080.INDX, 电子)
# 002475.XSHE    (801080.INDX, 电子)
# 300017.XSHE    (801770.INDX, 通信)
# 002065.XSHE   (801750.INDX, 计算机)
# 601985.XSHG  (801160.INDX, 公用事业)
# 002236.XSHE   (801750.INDX, 计算机)
# 601988.XSHG    (801780.INDX, 银行)
# 600871.XSHG    (801020.INDX, 采掘)
# 000709.XSHE    (801040.INDX, 钢铁)
# 600085.XSHG  (801150.INDX, 医药生物)
# 600900.XSHG  (801160.INDX, 公用事业)
# 002081.XSHE  (801720.INDX, 建筑装饰)
# 600352.XSHG    (801030.INDX, 化工)
# 600271.XSHG   (801750.INDX, 计算机)
# 600999.XSHG  (801790.INDX, 非银金融)
# 601899.XSHG  (801050.INDX, 有色金属)
# 600498.XSHG    (801770.INDX, 通信)
# 000876.XSHE  (801010.INDX, 农林牧渔)
# 300144.XSHE  (801210.INDX, 休闲服务)
# 601018.XSHG  (801170.INDX, 交通运输)
# 600150.XSHG  (801740.INDX, 国防军工)
#
# [300 rows x 1 columns]

# %%
market_cap_ = market_cap.loc[market_cap.items[0]].transpose()
result = pd.concat([benchmark, market_cap_], axis=1)
column_names = result.columns.values
column_names[1] = "market_cap"
result.columns = column_names
result
# Out:
#                         industry   market_cap
# 000001.XSHE    (801780.INDX, 银行)  1.56251e+11
# 000002.XSHE   (801180.INDX, 房地产)  2.26855e+11
# 000008.XSHE  (801050.INDX, 有色金属)  2.61806e+10
# 000009.XSHE    (801230.INDX, 综合)  2.22672e+10
# 000027.XSHE  (801160.INDX, 公用事业)  2.72361e+10
# 000039.XSHE  (801890.INDX, 机械设备)  4.35436e+10
# 000060.XSHE  (801050.INDX, 有色金属)  2.46708e+10
# 000061.XSHE  (801200.INDX, 商业贸易)  2.09914e+10
# 000063.XSHE    (801770.INDX, 通信)  6.62602e+10
# 000069.XSHE   (801180.INDX, 房地产)  5.70295e+10
# 000100.XSHE  (801110.INDX, 家用电器)  4.03051e+10
# 000156.XSHE    (801760.INDX, 传媒)  2.56713e+10
# 000157.XSHE  (801890.INDX, 机械设备)  3.47952e+10
# 000166.XSHE  (801790.INDX, 非银金融)  1.25354e+11
# 000333.XSHE  (801110.INDX, 家用电器)   1.8099e+11
# 000338.XSHE    (801880.INDX, 汽车)  3.98262e+10
# 000402.XSHE   (801180.INDX, 房地产)   3.0786e+10
# 000413.XSHE    (801080.INDX, 电子)  5.56236e+10
# 000415.XSHE  (801790.INDX, 非银金融)  4.42193e+10
# 000423.XSHE  (801150.INDX, 医药生物)  3.52321e+10
# 000425.XSHE  (801890.INDX, 机械设备)  2.36861e+10
# 000503.XSHE  (801150.INDX, 医药生物)  3.77955e+10
# 000538.XSHE  (801150.INDX, 医药生物)  7.93026e+10
# 000540.XSHE   (801180.INDX, 房地产)  3.24947e+10
# 000555.XSHE   (801750.INDX, 计算机)  2.04536e+10
# 000559.XSHE    (801880.INDX, 汽车)  3.04224e+10
# 000568.XSHE  (801120.INDX, 食品饮料)  4.62743e+10
# 000623.XSHE  (801150.INDX, 医药生物)  2.77186e+10
# 000625.XSHE    (801880.INDX, 汽车)  7.17516e+10
# 000627.XSHE    (801030.INDX, 化工)  3.25828e+10
# ...                          ...          ...
# 601628.XSHG  (801790.INDX, 非银金融)  6.80897e+11
# 601633.XSHG    (801880.INDX, 汽车)  1.00948e+11
# 601668.XSHG  (801720.INDX, 建筑装饰)    2.658e+11
# 601669.XSHG  (801720.INDX, 建筑装饰)  9.98586e+10
# 601688.XSHG  (801790.INDX, 非银金融)  1.27927e+11
# 601718.XSHG  (801130.INDX, 纺织服装)   3.5523e+10
# 601727.XSHG  (801730.INDX, 电气设备)   1.1309e+11
# 601766.XSHG  (801890.INDX, 机械设备)  2.66611e+11
# 601788.XSHG  (801790.INDX, 非银金融)  7.37265e+10
# 601800.XSHG  (801720.INDX, 建筑装饰)  2.45694e+11
# 601818.XSHG    (801780.INDX, 银行)  1.82515e+11
# 601857.XSHG    (801020.INDX, 采掘)  1.45502e+12
# 601866.XSHG  (801170.INDX, 交通运输)  4.76672e+10
# 601872.XSHG  (801170.INDX, 交通运输)  2.61793e+10
# 601877.XSHG  (801730.INDX, 电气设备)  3.76385e+10
# 601888.XSHG  (801210.INDX, 休闲服务)  4.23687e+10
# 601899.XSHG  (801050.INDX, 有色金属)  7.19461e+10
# 601901.XSHG  (801790.INDX, 非银金融)   6.2564e+10
# 601919.XSHG  (801170.INDX, 交通运输)  5.35333e+10
# 601928.XSHG    (801760.INDX, 传媒)  2.66451e+10
# 601933.XSHG  (801200.INDX, 商业贸易)   4.6991e+10
# 601939.XSHG    (801780.INDX, 银行)  1.36006e+12
# 601958.XSHG  (801050.INDX, 有色金属)  2.46835e+10
# 601985.XSHG  (801160.INDX, 公用事业)  1.09892e+11
# 601988.XSHG    (801780.INDX, 银行)  1.01269e+12
# 601989.XSHG  (801740.INDX, 国防军工)  1.30184e+11
# 601998.XSHG    (801780.INDX, 银行)  3.13672e+11
# 603000.XSHG    (801760.INDX, 传媒)  1.95265e+10
# 603885.XSHG  (801170.INDX, 交通运输)  2.99074e+10
# 603993.XSHG  (801050.INDX, 有色金属)  6.28204e+10
#
# [300 rows x 2 columns]

# %%
result[result.industry==("801790.INDX", "非银金融")].sort_values("market_cap",ascending=False)
# Out:
#                         industry   market_cap
# 601628.XSHG  (801790.INDX, 非银金融)  6.80897e+11
# 601318.XSHG  (801790.INDX, 非银金融)  6.47669e+11
# 601601.XSHG  (801790.INDX, 非银金融)  2.51652e+11
# 600030.XSHG  (801790.INDX, 非银金融)  1.94598e+11
# 600837.XSHG  (801790.INDX, 非银金融)  1.81152e+11
# 601211.XSHG  (801790.INDX, 非银金融)  1.41749e+11
# 601336.XSHG  (801790.INDX, 非银金融)  1.36574e+11
# 000776.XSHE  (801790.INDX, 非银金融)  1.28492e+11
# 601688.XSHG  (801790.INDX, 非银金融)  1.27927e+11
# 002736.XSHE  (801790.INDX, 非银金融)   1.2751e+11
# 000166.XSHE  (801790.INDX, 非银金融)  1.25354e+11
# 600999.XSHG  (801790.INDX, 非银金融)  1.09402e+11
# 600958.XSHG  (801790.INDX, 非银金融)   9.6526e+10
# 002797.XSHE  (801790.INDX, 非银金融)  7.61772e+10
# 601788.XSHG  (801790.INDX, 非银金融)  7.37265e+10
# 601901.XSHG  (801790.INDX, 非银金融)   6.2564e+10
# 002673.XSHE  (801790.INDX, 非银金融)   5.8064e+10
# 600061.XSHG  (801790.INDX, 非银金融)  5.76657e+10
# 000783.XSHE  (801790.INDX, 非银金融)  5.65665e+10
# 601198.XSHG  (801790.INDX, 非银金融)  5.53247e+10
# 600705.XSHG  (801790.INDX, 非银金融)  5.49351e+10
# 601377.XSHG  (801790.INDX, 非银金融)  5.12295e+10
# 600816.XSHG  (801790.INDX, 非银金融)  4.89322e+10
# 000415.XSHE  (801790.INDX, 非银金融)  4.42193e+10
# 600369.XSHG  (801790.INDX, 非银金融)  4.02496e+10
# 601555.XSHG  (801790.INDX, 非银金融)    3.981e+10
# 600109.XSHG  (801790.INDX, 非银金融)  3.94074e+10
# 000728.XSHE  (801790.INDX, 非银金融)  3.90856e+10
# 601099.XSHG  (801790.INDX, 非银金融)   3.5104e+10
# 002500.XSHE  (801790.INDX, 非银金融)  3.40013e+10
# 000750.XSHE  (801790.INDX, 非银金融)  2.93823e+10
# 000686.XSHE  (801790.INDX, 非银金融)   2.8928e+10
# 000712.XSHE  (801790.INDX, 非银金融)  2.10022e+10
# 600783.XSHG  (801790.INDX, 非银金融)  1.68374e+10
